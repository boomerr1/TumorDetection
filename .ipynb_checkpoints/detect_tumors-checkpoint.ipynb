# %% [markdown]
# ## Loading dependencies

# %%
import os
import cv2 as cv
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import ipywidgets as widgets
from IPython.display import display, clear_output

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %matplotlib inline

# %% [markdown]
# ## Creating convolutional neural network
# This step could have been fed through a pipeline, but I wanted to visualise the intermediate feature images.
#
# ### Feature extraction

# %%
IMAGE_PATH_NO = "tumordata/no/"
IMAGE_PATH_YES = "tumordata/yes/"

# %% [markdown]
# Although all images seem to be in greyscale, the RGB values differ in some pixels in some images.

# %%
# Converting images to greyscale
grey_imgs = [[], []]
for labelimgs, i in zip([IMAGE_PATH_YES, IMAGE_PATH_NO], range(2)):
    for file in os.listdir(labelimgs):
        img = cv.imread(labelimgs + file)
        grey_imgs[i].append(cv.cvtColor(img, cv.COLOR_BGR2GRAY))

# %%
# Plotting image sizes
shapes = []
for i in range(2):
    for j in range(len(grey_imgs[i])):
        shapes.append([len(grey_imgs[i][j]), len(grey_imgs[i][j][0])])
shapes = np.array(shapes)
with plt.style.context('ggplot'):
    sn.scatterplot(x=shapes[:,0], y=shapes[:,1])
    sn.scatterplot(x=[np.average(shapes[:,0])], y=[np.average(shapes[:,1])], s=150, label='Average', marker='X')
    sn.scatterplot(x=[np.min(shapes[:,0])], y=[np.min(shapes[:,1])], s=150, label='Smallest', marker='X')

# %%
# Resizing images
t_grey_imgs = copy.deepcopy(grey_imgs)
for i in range(2):
    for j in range(len(t_grey_imgs[i])):
        t_grey_imgs[i][j] = cv.resize(t_grey_imgs[i][j], (np.min(shapes[:,0]), np.min(shapes[:,1])), interpolation = cv.INTER_AREA)

# %matplotlib widget
import matplotlib.pyplot as plt

slider_yes = widgets.IntSlider(value=1, min=1, max=len(t_grey_imgs[0]))
slider_no = widgets.IntSlider(value=1, min=1, max=len(t_grey_imgs[1]))

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(10, 5, forward=True)
ax1.set_title("Brain with tumor")
ax2.set_title("Brain without tumor")
display(slider_yes)
display(slider_no)

def show_img_func_yes():
    i = slider_yes.value-1
    ax1.imshow(t_grey_imgs[0][i])

def show_img_func_no():
    i = slider_no.value-1
    ax2.imshow(t_grey_imgs[1][i])


slider_yes.observe(show_img_func_yes)
show_img_func_yes()

slider_no.observe(show_img_func_no)
show_img_func_no()
# Out:
# IntSlider(value=1, max=155, min=1)
# IntSlider(value=1, max=98, min=1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     538         # be locked when the hold_trait_notification context manager is
#     539         # released and notifications are fired.
# --> 540         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541             for name in sync_data:
#     542                 if name in self.keys:
#
# ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in _lock_property(self, **properties)
#     622         flawed.  In the future we may want to look into buffering state changes
#     623         back to the front-end."""
# --> 624         self._property_lock = properties
#     625         try:
#     626             yield
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# TypeError: show_img_func_yes() takes 0 positional arguments but 1 was given

# %%
# Splitting data
train_yes, test_yes = train_test_split(t_grey_imgs[0], test_size=0.2)
train_no, test_no = train_test_split(t_grey_imgs[1], test_size=0.2)
train_X = train_yes + train_no
train_y = len(train_yes)*[1] + len(train_no)*[0]
test_X = test_yes + test_no
test_y = len(test_yes)*[1] + len(test_no)*[0]

train_X, train_y = shuffle(train_X, train_y)

train_X_expanded = tf.expand_dims(train_X, axis=-1)
train_y = np.array(train_y).reshape((-1,1))

test_X_expanded = tf.expand_dims(test_X, axis=-1)
test_y = np.array(test_y).reshape((-1,1))

# %% [markdown]
# ### Creating neural network |

# %%
model = Sequential()
model.add(layers.Conv2D(3, (3,3), input_shape=(150, 168, 1)))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Conv2D(3, (3,3)))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(layers.Dense(300, activation='relu', kernel_regularizer='l2'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(layers.Dense(300, activation='relu', kernel_regularizer='l2'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
opt = tf.keras.optimizers.Adam(
    learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
)

model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 148, 166, 3)       30
#
#  max_pooling2d_12 (MaxPoolin  (None, 74, 83, 3)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 72, 81, 3)         84
#
#  max_pooling2d_13 (MaxPoolin  (None, 36, 40, 3)        0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 4320)              0
#
#  dense_24 (Dense)            (None, 300)               1296300
#
#  dropout_12 (Dropout)        (None, 300)               0
#
#  dense_25 (Dense)            (None, 300)               90300
#
#  dropout_13 (Dropout)        (None, 300)               0
#
#  dense_26 (Dense)            (None, 300)               90300
#
#  dense_27 (Dense)            (None, 1)                 301
#
# =================================================================
# Total params: 1,477,315
# Trainable params: 1,477,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
history = model.fit(train_X_expanded, train_y, epochs=50, batch_size=15, validation_data=(test_X_expanded, test_y))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 1s 49ms/step - loss: 102.5641 - accuracy: 0.5891 - val_loss: 13.3550 - val_accuracy: 0.7255
# Epoch 2/50
# 14/14 [==============================] - 0s 35ms/step - loss: 44.1271 - accuracy: 0.6188 - val_loss: 12.7776 - val_accuracy: 0.7451
# Epoch 3/50
# 14/14 [==============================] - 0s 36ms/step - loss: 28.7586 - accuracy: 0.6485 - val_loss: 22.6951 - val_accuracy: 0.7059
# Epoch 4/50
# 14/14 [==============================] - 1s 36ms/step - loss: 22.6407 - accuracy: 0.6782 - val_loss: 8.2780 - val_accuracy: 0.8235
# Epoch 5/50
# 14/14 [==============================] - 1s 36ms/step - loss: 11.4539 - accuracy: 0.7525 - val_loss: 6.8689 - val_accuracy: 0.8431
# Epoch 6/50
# 14/14 [==============================] - 0s 35ms/step - loss: 7.8212 - accuracy: 0.8416 - val_loss: 6.2381 - val_accuracy: 0.8431
# Epoch 7/50
# 14/14 [==============================] - 0s 35ms/step - loss: 7.3724 - accuracy: 0.8366 - val_loss: 6.7004 - val_accuracy: 0.8039
# Epoch 8/50
# 14/14 [==============================] - 0s 36ms/step - loss: 8.3966 - accuracy: 0.7772 - val_loss: 6.8753 - val_accuracy: 0.8039
# Epoch 9/50
# 14/14 [==============================] - 0s 35ms/step - loss: 9.1517 - accuracy: 0.7574 - val_loss: 7.3282 - val_accuracy: 0.8431
# Epoch 10/50
# 14/14 [==============================] - 1s 36ms/step - loss: 8.0177 - accuracy: 0.8515 - val_loss: 7.3667 - val_accuracy: 0.8431
# Epoch 11/50
# 14/14 [==============================] - 1s 37ms/step - loss: 6.8560 - accuracy: 0.8317 - val_loss: 6.0084 - val_accuracy: 0.8627
# Epoch 12/50
# 14/14 [==============================] - 0s 36ms/step - loss: 5.6171 - accuracy: 0.8812 - val_loss: 5.9536 - val_accuracy: 0.8627
# Epoch 13/50
50
# 14/14 [==============================] - 0s 36ms/step - loss: 4.2588 - accuracy: 0.9653 - val_loss: 6.5721 - val_accuracy: 0.8627
# Epoch 39/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.0493 - accuracy: 0.9802 - val_loss: 6.6930 - val_accuracy: 0.8627
# Epoch 40/50
# 14/14 [==============================] - 1s 37ms/step - loss: 4.1985 - accuracy: 0.9604 - val_loss: 7.3431 - val_accuracy: 0.8627
# Epoch 41/50
# 14/14 [==============================] - 0s 36ms/step - loss: 4.2448 - accuracy: 0.9653 - val_loss: 6.3490 - val_accuracy: 0.8431
# Epoch 42/50
# 14/14 [==============================] - 0s 36ms/step - loss: 3.9584 - accuracy: 0.9703 - val_loss: 6.3414 - val_accuracy: 0.8627
# Epoch 43/50
# 14/14 [==============================] - 0s 36ms/step - loss: 4.1689 - accuracy: 0.9257 - val_loss: 6.1868 - val_accuracy: 0.8824
# Epoch 44/50
# 14/14 [==============================] - 0s 36ms/step - loss: 4.0139 - accuracy: 0.9901 - val_loss: 6.1504 - val_accuracy: 0.8627
# Epoch 45/50
# 14/14 [==============================] - 0s 36ms/step - loss: 3.8766 - accuracy: 0.9802 - val_loss: 5.6795 - val_accuracy: 0.8431
# Epoch 46/50
# 14/14 [==============================] - 1s 36ms/step - loss: 3.8930 - accuracy: 0.9703 - val_loss: 5.8785 - val_accuracy: 0.8824
# Epoch 47/50
# 14/14 [==============================] - 0s 35ms/step - loss: 3.8149 - accuracy: 0.9851 - val_loss: 5.9310 - val_accuracy: 0.8627
# Epoch 48/50
# 14/14 [==============================] - 0s 36ms/step - loss: 3.9085 - accuracy: 0.9752 - val_loss: 6.1736 - val_accuracy: 0.8824
# Epoch 49/50
# 14/14 [==============================] - 0s 36ms/step - loss: 4.0417 - accuracy: 0.9752 - val_loss: 5.9482 - val_accuracy: 0.8824
# Epoch 50/50
# 14/14 [==============================] - 0s 36ms/step - loss: 3.8130 - accuracy: 0.9802 - val_loss: 6.0501 - val_accuracy: 0.8824

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

with plt.style.context('ggplot'):
    plt.plot(history.history['loss'], linewidth=0.7)
    plt.plot(history.history['val_loss'], linewidth=0.7)
    plt.title('model loss')
    plt.legend(['train', 'test'], loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-5240bd03fdab> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 with plt.style.context('ggplot'):
# ----> 3     plt.plot(history.history['loss'], linewidth=0.7)
#       4     plt.plot(history.history['val_loss'], linewidth=0.7)
#       5     plt.title('model loss')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Plotting false negatives and false positives

# %%
test_y_pred = model.predict(test_X_expanded)
test_y_pred = (test_y_pred > 0.5).astype(int)

false_negatives, false_positives = [], []
for pred_label, true_label, i in zip(test_y_pred, test_y, range(len(test_y))):
    if pred_label == 1 and true_label == 0:
        false_positives.append(i)
    if pred_label == 0 and true_label == 1:
        false_negatives.append(i)

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 5, forward=True)
fig.suptitle('False negatives')
if len(false_negatives) < 2:
    for false_neg, i in zip(false_negatives, range(len(false_negatives))):
        ax[i].imshow(test_X[false_neg])
        ax[i].set_title('Brain with tumor')
else:
    false_negatives_samples = np.random.choice(false_negatives, 2, replace=False)
    ax[0].imshow(test_X[false_negatives_samples[0]])
    ax[0].set_title('Brain with tumor')
    ax[1].imshow(test_X[false_negatives_samples[1]])
    ax[1].set_title('Brain with tumor')

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 5, forward=True)
fig.suptitle('False positives')
if len(false_positives) < 2:
    for false_pos, i in zip(false_positives, range(len(false_positives))):
        ax[i].imshow(test_X[false_pos])
        ax[i].set_title('Healthy brain')
else:
    false_positives_samples = np.random.choice(false_positives, 2, replace=False)
    ax[0].imshow(test_X[false_positives_samples[0]])
    ax[0].set_title('Healthy brain')
    ax[1].imshow(test_X[false_positives_samples[1]])
    ax[1].set_title('Healthy brain')

# %% [markdown]
# ## Seeing the model in action
# Given are four people with their MRI scan, two of which have a tumor in their brain and two of which do not.

# %%
img1 = cv.imread("tumordata/healthy_brain.jpg")
img2 = cv.imread("tumordata/healthy_brain2.jpg")
img3 = cv.imread("tumordata/sick_brain.jpeg")
img4 = cv.imread("tumordata/sick_brain2.jpeg")

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(10, 5, forward=True)

ax1.imshow(img1)
ax1.set_title('Person 1')
ax2.imshow(img2)
ax2.set_title('Person 2')
fig.suptitle('Healthy brains')

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(10, 5, forward=True)

ax1.imshow(img3)
ax1.set_title('Person 3')
ax2.imshow(img4)
ax2.set_title('Person 4')
fig.suptitle('Brains with tumor');

# %% [markdown]
# #### Checking whether the images are new

# %%
no_imgs = [img1, img2]
yes_imgs = [img3, img4]

for img in no_imgs:
    grey_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    for shape, i in zip(shapes[155:], range(len(shapes[155:]))):
        if set(shape) == set(grey_img.shape):
            if (grey_img == grey_imgs[1][i]).all():
                plt.imshow(grey_imgs[1][i])

for img in yes_imgs:
    grey_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    for shape, i in zip(shapes[:155], range(len(shapes[:155]))):
        if set(shape) == set(grey_img.shape):
            if (grey_img == grey_imgs[0][i]).all():
                plt.imshow(grey_imgs[0][i])

# %% [markdown]
# There are no images plotted, so the new images are not contained in the training and test data.

# %% [markdown]
# #### Predicting the healthiness of the brains

# %%
# ---This makes sure the cell can be re-run---
# img1 = cv.imread("tumordata/healthy_brain.jpg")
# img2 = cv.imread("tumordata/healthy_brain2.jpg")
# img3 = cv.imread("tumordata/sick_brain.jpeg")
# img4 = cv.imread("tumordata/sick_brain2.jpeg")
# --------------------------------------------

for img, person_id in zip([img1, img2, img3, img4], range(1, len([img1, img2, img3, img4])+1)):
    img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    img = cv.resize(img, (np.min(shapes[:,0]), np.min(shapes[:,1])), interpolation = cv.INTER_AREA)
    img = tf.expand_dims(img, axis=-1)
    res = model.predict(np.array([img]))[0][0]
    if res > 0.5:
        print("Person", person_id,"probably has a brain tumor with a confidence of:", res)
    else:
        print("Person", person_id,"probably doesn't have a brain tumor with a confidence of:", 1-res)
# Out:
# Person 1 probably doesn't have a brain tumor with a confidence of: 0.9999999991083555
# Person 2 probably doesn't have a brain tumor with a confidence of: 0.9999999999999932
# Person 3 probably has a brain tumor with a confidence of: 0.99999976
# Person 4 probably has a brain tumor with a confidence of: 0.9998105
